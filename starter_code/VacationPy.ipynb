# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
pip install gmaps
# Out:
# Collecting gmaps
#   Downloading gmaps-0.9.0.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 3.7 MB/s eta 0:00:01
# Requirement already satisfied: ipython>=5.3.0 in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from gmaps) (7.19.0)
# Collecting ipywidgets>=7.0.0
#   Downloading ipywidgets-7.6.3-py2.py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 52.8 MB/s eta 0:00:01
# Requirement already satisfied: traitlets>=4.3.0 in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from gmaps) (5.0.5)
# Collecting geojson>=2.0.0
#   Downloading geojson-2.5.0-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: six in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from gmaps) (1.15.0)
# Requirement already satisfied: pickleshare in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (3.0.8)
# Requirement already satisfied: backcall in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: pygments in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (2.7.3)
# Requirement already satisfied: decorator in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (4.4.2)
# Requirement already satisfied: pexpect>4.3 in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (4.8.0)
# Requirement already satisfied: jedi>=0.10 in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (0.17.2)
# Requirement already satisfied: appnope in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (0.1.2)
# Requirement already satisfied: setuptools>=18.5 in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (51.0.0.post20201207)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from ipywidgets>=7.0.0->gmaps) (5.3.4)
# Collecting widgetsnbextension~=3.5.0
#   Downloading widgetsnbextension-3.5.1-py2.py3-none-any.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 119.1 MB/s eta 0:00:01
# Collecting jupyterlab-widgets>=1.0.0
#   Downloading jupyterlab_widgets-1.0.0-py3-none-any.whl (243 kB)
#      |████████████████████████████████| 243 kB 103.1 MB/s eta 0:00:01
# Requirement already satisfied: nbformat>=4.2.0 in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from ipywidgets>=7.0.0->gmaps) (5.0.8)
# Requirement already satisfied: tornado>=4.2 in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1)
# Requirement already satisfied: jupyter-client in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1.7)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from jedi>=0.10->ipython>=5.3.0->gmaps) (0.7.0)
# Requirement already satisfied: jupyter-core in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.7.0)
# Requirement already satisfied: ipython-genutils in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.17.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from pexpect>4.3->ipython>=5.3.0->gmaps) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.1.6)
# Requirement already satisfied: nbconvert in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.0.7)
# Requirement already satisfied: argon2-cffi in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.1.0)
# Requirement already satisfied: prometheus-client in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.9.0)
# Requirement already satisfied: pyzmq>=17 in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.0.0)
# Requirement already satisfied: Send2Trash in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: jinja2 in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.2)
# Requirement already satisfied: terminado>=0.8.3 in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.9.2)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.1)
# Requirement already satisfied: cffi>=1.0.0 in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.14.4)
# Requirement already satisfied: pycparser in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: testpath in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.1.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: bleach in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.2.1)
# Requirement already satisfied: defusedxml in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: nest-asyncio in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.3)
# Requirement already satisfied: async-generator in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.10)
# Requirement already satisfied: packaging in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.8)
# Requirement already satisfied: webencodings in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/marcellisv/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.4.7)
# Building wheels for collected packages: gmaps
#   Building wheel for gmaps (setup.py) ... done
#   Created wheel for gmaps: filename=gmaps-0.9.0-py2.py3-none-any.whl size=2076097 sha256=cca645a6a3f9a00faaa6deefb52817d96ba110d06e69e69a825b4c7519f6d6cb
#   Stored in directory: /Users/marcellisv/Library/Caches/pip/wheels/30/bd/87/d0d731ee712c34a4d6bace8b1dbf8c8932e22a1625b4a55be4
# Successfully built gmaps
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, ipywidgets, geojson, gmaps
# Successfully installed geojson-2.5.0 gmaps-0.9.0 ipywidgets-7.6.3 jupyterlab-widgets-1.0.0 widgetsnbextension-3.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key
g_key = "AIzaSyDQFfnkx5DSDq6hEuJSj2ASL2jtZiAW_Wg"

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
cities_data = pd.read_csv("../cities.csv")
cities_data.dropna()
cities_data.head()
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05
# 1        1  mahebourg          75      MU  1558378503        74 -20.41
# 2        2    qaanaaq          25      GL  1558378755        73  77.48
# 3        3     zhuhai           0      CN  1558378755        39  40.71
# 4        4  cape town          20      ZA  1558378755        76 -33.93
#
#       Lng  Max Temp  Wind Speed
# 0   39.51     37.50        7.16
# 1   57.70     78.80       11.41
# 2  -69.36     22.20        2.37
# 3  112.04     44.60        4.47
# 4   18.42     55.99        8.05

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(g_key)

# %%
locations = cities_data [["Lat", "Lng"]]
Humidity = cities_data["Humidity"].astype(float)

# %%
fig = gmaps.figure(center = [0,0] ,zoom_level = 2)

heat_layer = gmaps.heatmap_layer (locations, weights=Humidity,
                                 dissipating=False, max_intensity=100)
fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
hotel_df = cities_data.loc[(cities_data['Max Temp'] >= 70) & (cities_data ['Max Temp'] <= 80) & (cities_data ['Cloudiness']==0) & (cities_data ['Wind Speed'] < 10)]
hotel_df
# Out:
#      City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 7          7         opuwo           0     NaN  1558378523        23 -18.06
# 70        70  ponta do sol           0      BR  1558378767        57 -20.63
# 88        88      cidreira           0      BR  1558378770        66 -30.17
# 138      138     morondava           0      MG  1558378780        69 -20.30
# 139      139         vaini           0      IN  1558378780        88  15.34
# 176      176         nador           0      MA  1558378499        40  35.17
# 297      297         mogok           0      MM  1558378844        51  22.92
# 444      444       birjand           0      IR  1558378880        26  32.86
#
#        Lng  Max Temp  Wind Speed
# 7    13.84     72.06        5.44
# 70  -46.00     73.68        5.32
# 88  -50.22     76.56        5.50
# 138  44.28     79.08        9.06
# 139  74.49     78.90        1.59
# 176  -2.93     75.20        6.93
# 297  96.51     72.24        2.77
# 444  59.22     71.60        9.17

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df["Hotel Name"]=''
params = {
    "radius": 5000,
    "types": "hotel",
    "keyword": "hotel",
    "key": g_key,
    "location": "23.61,58.59"
}

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
hotel_name = requests.get(base_url, params=params)
    
hotel_name = name_address.json()

hotel_name
hotel_df
# Out:
# <ipython-input-46-06028965efc9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df["Hotel Name"]=''
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-06028965efc9> in <module>
#      12 hotel_name = requests.get(base_url, params=params)
#      13
# ---> 14 hotel_name = name_address.json()
#      15
#      16 hotel_name
#
# AttributeError: 'dict' object has no attribute 'json'

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map

locations = city_data[""]
# Display figure
